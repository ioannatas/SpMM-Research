# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # Reading double data

# %%
data1 = pd.read_csv('validation_n=32/mkl_gemm_d.csv')
data_gemm_32_d = [row[6] for row in data1.values if not np.isnan(row[5])]
data2 = pd.read_csv('validation_n=64/mkl_gemm_d.csv')
data_gemm_64_d = [row[6] for row in data2.values if not np.isnan(row[5])]
data3 = pd.read_csv('validation_n=128/mkl_gemm_d.csv')
data_gemm_128_d = [row[6] for row in data3.values if not np.isnan(row[5])]
data4 = pd.read_csv('validation_n=256/mkl_gemm_d.csv')
data_gemm_256_d = [row[6] for row in data4.values if not np.isnan(row[5])]
data5 = pd.read_csv('validation_n=512/mkl_gemm_d.csv')
data_gemm_512_d = [row[6] for row in data5.values if not np.isnan(row[5])]
data6 = pd.read_csv('validation_n=350/mkl_gemm_d.csv')
data_gemm_350_d = [row[7] for row in data6.values if not np.isnan(row[5])]
data7 = pd.read_csv('validation_n=42/mkl_gemm_d.csv')
data_gemm_42_d = [row[7] for row in data7.values if not np.isnan(row[5])]

gemm_matrices = [row[0][51:-4] for row in data5.values if not np.isnan(row[5])]
print(gemm_matrices)
data_gemm_d = data_gemm_32_d +data_gemm_42_d + data_gemm_64_d +  data_gemm_128_d + data_gemm_256_d+ data_gemm_350_d + data_gemm_512_d
# print(data_gemm)

data1 = pd.read_csv('validation_n=32/mkl_csr_d.csv')
data_csr_32_d = [row[7] for row in data1.values if not np.isnan(row[5])]
data2 = pd.read_csv('validation_n=64/mkl_csr_d.csv')
data_csr_64_d = [row[7] for row in data2.values if not np.isnan(row[5])]
data3 = pd.read_csv('validation_n=128/mkl_csr_d.csv')
data_csr_128_d = [row[6] for row in data3.values if not np.isnan(row[5])]
data4 = pd.read_csv('validation_n=256/mkl_csr_d.csv')
data_csr_256_d = [row[7] for row in data4.values if not np.isnan(row[5])]
data5 = pd.read_csv('validation_n=512/mkl_csr_d.csv')
data_csr_512_d = [row[7] for row in data5.values if not np.isnan(row[5])]
data6 = pd.read_csv('validation_n=350/mkl_csr_d.csv')
data_csr_350_d = [row[7] for row in data6.values if not np.isnan(row[5])]
data7 = pd.read_csv('validation_n=42/mkl_csr_d.csv')
data_csr_42_d = [row[7] for row in data7.values if not np.isnan(row[5])]

csr_matrices = [row[0][51:-4] for row in data1.values]
print(csr_matrices)
data_csr_d = data_csr_32_d+ data_csr_42_d+ data_csr_64_d +  data_csr_128_d + data_csr_256_d +data_csr_350_d + data_csr_512_d
# print(data_csr)
print()

data6 = pd.read_csv('validation_spmv/mkl_csr_d.csv')
data_spmv_d = [row[6] for row in data6.values if not np.isnan(row[5])]
# Out:
# ['scircuit', 'raefsky3', 'rgg_n_2_17_s0', 'bbmat', 'appu', 'rma10', 'cop20k_A', 'cant', 'pdb1HYS', 'TSOPF_RS_b300_c3', 'Chebyshev4', 'consph', 'shipsec1', 'PR02R', 'gupta3', 'mip1', 'rail4284', 'crankseg_2', 'TSOPF_RS_b2383', 'human_gene1']
# ['scircuit', 'mac_econ_fwd500', 'raefsky3', 'rgg_n_2_17_s0', 'bbmat', 'appu', 'mc2depi', 'rma10', 'cop20k_A', 'thermomech_dK', 'webbase-1M', 'cant', 'ASIC_680k', 'roadNet-TX', 'pdb1HYS', 'TSOPF_RS_b300_c3', 'Chebyshev4', 'consph', 'com-Youtube', 'rajat30', 'radiation', 'Stanford_Berkeley', 'shipsec1', 'PR02R', 'CurlCurl_2', 'gupta3', 'mip1', 'rail4284', 'pwtk', 'crankseg_2', 'Si41Ge41H72', 'TSOPF_RS_b2383', 'in-2004', 'Ga41As41H72', 'eu-2005', 'wikipedia-20051105', 'kron_g500-logn18', 'rajat31', 'human_gene1', 'delaunay_n22', 'GL7d20', 'sx-stackoverflow', 'dgreen', 'mawi_201512012345', 'ldoor', 'dielFilterV2real', 'circuit5M', 'soc-LiveJournal1', 'bone010', 'audikw_1', 'cage15', 'kmer_V2a']

# %%
print(data_spmv_d)
print(512,data_csr_512_d)
print(350,data_csr_350_d)
print(128,data_csr_128_d)
print(256,data_csr_256_d)
print(data_csr_42_d)
print(32,data_csr_32_d)
print(64,data_csr_64_d)
# Out:
# [26.221944, 43.280828, 71.522335, 27.765275, 60.181358, 57.441952, 43.286549, 52.680561, 32.262965, 44.774946, 12.214625, 78.935952, 14.303176, 18.285551, 77.225468, 50.32664, 6.64747, 80.148899, 3.882663, 12.739615, 40.10705, 25.74167, 76.246635, 78.161314, 50.657461, 11.064177, 10.623163, 8.390342, 50.161436, 16.216764, 13.729978, 9.695116, 8.727645, 12.889027, 10.397405, 4.083058, 11.3351, 7.547417, 12.244118, 5.291698, 6.864019, 2.419191, 9.170459, 2.796565, 11.148291, 10.268228, 3.968897, 3.023316, 11.921712, 9.851379, 9.103435, 2.382366]
# ...

# %%
print(data_spmv_d)
print(512,data_gemm_512_d)
print(350,data_gemm_350_d)
print(128,data_gemm_128_d)
print(256,data_gemm_256_d)
print(data_gemm_42_d)
print(32,data_gemm_32_d)
print(64,data_gemm_64_d)
# Out:
# [26.221944, 43.280828, 71.522335, 27.765275, 60.181358, 57.441952, 43.286549, 52.680561, 32.262965, 44.774946, 12.214625, 78.935952, 14.303176, 18.285551, 77.225468, 50.32664, 6.64747, 80.148899, 3.882663, 12.739615, 40.10705, 25.74167, 76.246635, 78.161314, 50.657461, 11.064177, 10.623163, 8.390342, 50.161436, 16.216764, 13.729978, 9.695116, 8.727645, 12.889027, 10.397405, 4.083058, 11.3351, 7.547417, 12.244118, 5.291698, 6.864019, 2.419191, 9.170459, 2.796565, 11.148291, 10.268228, 3.968897, 3.023316, 11.921712, 9.851379, 9.103435, 2.382366]
# 512 [837.057171, 884.842754, 858.326713, 891.460828, 901.334464, 890.972043, 901.359539, 909.078357, 894.718905, 896.222601, 912.00684, 908.604313, 851.299622, 837.361217, 892.943734, 908.856332, 869.798886, 908.200624, 891.497681, 880.657298]
# ...

# %% [markdown]
# # Reading float data

# %%
data1 = pd.read_csv('validation_n=32/mkl_gemm_f.csv')
data_gemm_32_f = [row[7] for row in data1.values if not np.isnan(row[5])]
data2 = pd.read_csv('validation_n=64/mkl_gemm_f.csv')
data_gemm_64_f = [row[7] for row in data2.values if not np.isnan(row[5])]
data3 = pd.read_csv('validation_n=128/mkl_gemm_f.csv')
data_gemm_128_f = [row[7] for row in data3.values if not np.isnan(row[5])]
data4 = pd.read_csv('validation_n=256/mkl_gemm_f.csv')
data_gemm_256_f = [row[7] for row in data4.values if not np.isnan(row[5])]
data5 = pd.read_csv('validation_n=512/mkl_gemm_f.csv')
data_gemm_512_f = [row[7] for row in data5.values if not np.isnan(row[5])]
data4 = pd.read_csv('validation_n=256/mkl_gemm_f.csv')
data_gemm_256_f = [row[7] for row in data4.values if not np.isnan(row[5])]
data5 = pd.read_csv('validation_n=512/mkl_gemm_f.csv')
data_gemm_512_f = [row[7] for row in data5.values if not np.isnan(row[5])]
data6 = pd.read_csv('validation_n=42/mkl_gemm_f.csv')
data_gemm_42_f = [row[7] for row in data6.values if not np.isnan(row[5])]
data7 = pd.read_csv('validation_n=350/mkl_gemm_f.csv')
data_gemm_350_f = [row[7] for row in data7.values if not np.isnan(row[5])]

data_gemm_f = data_gemm_32_f +  data_gemm_42_f + data_gemm_64_f + data_gemm_128_f + data_gemm_256_f +data_gemm_350_f + data_gemm_512_f 
# print(data_gemm)

data1 = pd.read_csv('validation_n=32/mkl_csr_f.csv')
data_csr_32_f = [row[7] for row in data1.values if not np.isnan(row[5])]
data2 = pd.read_csv('validation_n=64/mkl_csr_f.csv')
data_csr_64_f = [row[7] for row in data2.values if not np.isnan(row[5])]
data3 = pd.read_csv('validation_n=128/mkl_csr_f.csv')
data_csr_128_f = [row[7] for row in data3.values if not np.isnan(row[5])]
data4 = pd.read_csv('validation_n=256/mkl_csr_f.csv')
data_csr_256_f = [row[7] for row in data4.values if not np.isnan(row[5])]
data5 = pd.read_csv('validation_n=512/mkl_csr_f.csv')
data_csr_512_f = [row[7] for row in data5.values if not np.isnan(row[5])]
data6 = pd.read_csv('validation_n=42/mkl_csr_f.csv')
data_csr_42_f = [row[7] for row in data6.values if not np.isnan(row[5])]
data7 = pd.read_csv('validation_n=350/mkl_csr_f.csv')
data_csr_350_f = [row[7] for row in data7.values if not np.isnan(row[5])]

data_csr_f = data_csr_32_f+ data_csr_64_f +  data_csr_42_f + data_csr_128_f + data_csr_256_f + data_csr_350_f + data_csr_512_f
# print(data_csr)

data6 = pd.read_csv('validation_spmv/mkl_csr_f.csv')
data_spmv_f = [row[6] for row in data6.values if not np.isnan(row[5])]

# %% [markdown]
# # Double Box Plots

# %%
# print(data_spmv)
data = [data_spmv_d, data_csr_d, data_gemm_d]
# print(data)
# Create a box plot
plt.figure(figsize=(10, 6))
plt.boxplot(data, patch_artist=True)

# Customizing labels and title
plt.title('Double-All column sizes')
# plt.xlabel('')
custom_labels = ['SpMV', 'SpMM', 'GEMM']
plt.xticks(np.arange(1, len(custom_labels) + 1), custom_labels)
plt.ylabel('GFLOPs')

# Show the plot
plt.show()

# %%
print(np.median(data_spmv_d))
print(np.median(data_csr_d))
print(np.median(data_gemm_d))
# Out:
# 12.4918665
# 42.6542475
# 792.107542

# %%
# print(data_spmv)
data = [data_spmv_d, data_csr_512_d, data_gemm_512_d]
# print(data)
# Create a box plot
plt.figure(figsize=(10, 6))
plt.boxplot(data, patch_artist=True)

# Customizing labels and title
plt.title('N=512')
plt.xticks(np.arange(1, len(custom_labels) + 1), custom_labels)
plt.ylabel('GLOPs')

# Show the plot
plt.show()

# %%
# print(data_spmv)
data = [data_spmv_d, data_csr_256_d]
# print(data)
# Create a box plot
plt.figure(figsize=(10, 6))
plt.boxplot(data, patch_artist=True)

# Customizing labels and title
plt.title('N=256')
custom_labels = ['SpMV', 'SpMM']
plt.xticks(np.arange(1, len(custom_labels) + 1), custom_labels)
plt.ylabel('GFLOPs')

# Show the plot
plt.show()

# %%
# print(data_spmv)
data = [data_spmv_d, data_csr_32_d, data_csr_42_d, data_csr_64_d,data_csr_128_d, data_csr_256_d, data_csr_350_d, data_csr_512_d]
# print(data)
# Create a box plot
plt.figure(figsize=(10, 6))
plt.boxplot(data, patch_artist=True)

# Customizing labels and title
plt.title('SpMM-different column sizes')
custom_labels = ['1','32', '42', '64', '128', '256', '350', '512']
plt.xticks(np.arange(1, len(custom_labels) + 1), custom_labels)
plt.ylabel('GFLOPs')

# Show the plot
plt.show()

# %%
# print(data_spmv)
data = [ data_gemm_32_d, data_gemm_42_d, data_gemm_64_d,data_gemm_128_d, data_gemm_256_d, data_gemm_350_d, data_gemm_512_d]
# print(data)
# Create a box plot
plt.figure(figsize=(10, 6))
plt.boxplot(data, patch_artist=True)

# Customizing labels and title
plt.title('SpMM-different column sizes')
custom_labels = ['32', '42', '64', '128', '256', '350', '512']
plt.xticks(np.arange(1, len(custom_labels) + 1), custom_labels)
plt.ylabel('GFLOPs')

# Show the plot
plt.show()

# %% [markdown]
# # Float Box Plots

# %%
# print(data_spmv)
data = [data_spmv_f, data_csr_f, data_gemm_f]
# print(data)
# Create a box plot
plt.figure(figsize=(10, 6))
plt.boxplot(data, patch_artist=True)

# Customizing labels and title
plt.title('Float-All column sizes')
# plt.xlabel('')
custom_labels = ['SpMV', 'SpMM', 'GEMM']
plt.xticks(np.arange(1, len(custom_labels) + 1), custom_labels)
plt.ylabel('GFLOPs')

# Show the plot
plt.show()

# %%
print(np.median(data_spmv_f))
print(np.median(data_csr_f))
print(np.median(data_gemm_f))
# Out:
# 18.980942
# 129.561588
# 1643.2906615

# %%
# print(data_spmv)
data = [data_spmv_f, data_csr_f]
# print(data)
# Create a box plot
plt.figure(figsize=(10, 6))
plt.boxplot(data, patch_artist=True)

# Customizing labels and title
plt.title('Float-All column sizes')
# plt.xlabel('')
custom_labels = ['SpMV', 'SpMM']
plt.xticks(np.arange(1, len(custom_labels) + 1), custom_labels)
plt.ylabel('GFLOPs')

# Show the plot
plt.show()

# %%
# print(data_spmv)
data = [data_spmv_f, data_csr_32_f, data_csr_42_f, data_csr_64_f,data_csr_128_f, data_csr_256_f, data_csr_350_f, data_csr_512_f]
# print(data)
# Create a box plot
plt.figure(figsize=(10, 6))
plt.boxplot(data, patch_artist=True)

# Customizing labels and title
plt.title('SpMM-different column sizes')
custom_labels = ['1','32', '42', '64', '128', '256', '350', '512']
plt.xticks(np.arange(1, len(custom_labels) + 1), custom_labels)
plt.ylabel('GFLOPs')

# Show the plot
plt.show()

# %%
# print(data_spmv)
data = [data_gemm_32_f, data_gemm_42_f, data_gemm_64_f,data_gemm_128_f, data_gemm_256_f, data_gemm_350_f, data_gemm_512_f]
# print(data)
# Create a box plot
plt.figure(figsize=(10, 6))
plt.boxplot(data, patch_artist=True)

# Customizing labels and title
plt.title('GEMM-different column sizes')
custom_labels = ['32', '42', '64', '128', '256', '350', '512']
plt.xticks(np.arange(1, len(custom_labels) + 1), custom_labels)
plt.ylabel('GFLOPs')

# Show the plot
plt.show()

# %% [markdown]
# # General Plots

# %%
data1 = pd.read_csv('validation_n=32/mkl_csr_d.csv')
data_csr_32_d = [row[7] if not np.isnan(row[7]) else 0 for row in data1.values ]
data2 = pd.read_csv('validation_n=64/mkl_csr_d.csv')
data_csr_64_d = [row[7] if not np.isnan(row[7]) else 0 for row in data2.values ]
data3 = pd.read_csv('validation_n=128/mkl_csr_d.csv')
data_csr_128_d = [row[6] if not np.isnan(row[6]) else 0 for row in data3.values ]
data4 = pd.read_csv('validation_n=256/mkl_csr_d.csv')
data_csr_256_d = [row[7] if not np.isnan(row[7]) else 0 for row in data4.values ]
data5 = pd.read_csv('validation_n=512/mkl_csr_d.csv')
data_csr_512_d = [row[7] if not np.isnan(row[7]) else 0 for row in data5.values ]
data7 = pd.read_csv('validation_n=42/mkl_csr_d.csv')
data_csr_42_d = [row[7] if not np.isnan(row[7]) else 0 for row in data7.values ]
data8 = pd.read_csv('validation_n=350/mkl_csr_d.csv')
data_csr_350_d = [row[7] if not np.isnan(row[7]) else 0 for row in data8.values ]

csr_matrices = [row[0][51:-4] for row in data1.values]
print(csr_matrices)
data_csr_d = data_csr_32_d+ data_csr_42_d+ data_csr_64_d +  data_csr_128_d + data_csr_256_d +data_csr_350_d + data_csr_512_d
# print(data_csr)

data6 = pd.read_csv('validation_spmv/mkl_csr_d.csv')
data_spmv_d = [row[6] if not np.isnan(row[6]) else 0 for row in data6.values ]
# Out:
# ['scircuit', 'mac_econ_fwd500', 'raefsky3', 'rgg_n_2_17_s0', 'bbmat', 'appu', 'mc2depi', 'rma10', 'cop20k_A', 'thermomech_dK', 'webbase-1M', 'cant', 'ASIC_680k', 'roadNet-TX', 'pdb1HYS', 'TSOPF_RS_b300_c3', 'Chebyshev4', 'consph', 'com-Youtube', 'rajat30', 'radiation', 'Stanford_Berkeley', 'shipsec1', 'PR02R', 'CurlCurl_2', 'gupta3', 'mip1', 'rail4284', 'pwtk', 'crankseg_2', 'Si41Ge41H72', 'TSOPF_RS_b2383', 'in-2004', 'Ga41As41H72', 'eu-2005', 'wikipedia-20051105', 'kron_g500-logn18', 'rajat31', 'human_gene1', 'delaunay_n22', 'GL7d20', 'sx-stackoverflow', 'dgreen', 'mawi_201512012345', 'ldoor', 'dielFilterV2real', 'circuit5M', 'soc-LiveJournal1', 'bone010', 'audikw_1', 'cage15', 'kmer_V2a']

# %%
data1 = pd.read_csv('validation_n=32/mkl_csr_f.csv')
data_csr_32_f = [row[7] if not np.isnan(row[7]) else 0 for row in data1.values ]
data2 = pd.read_csv('validation_n=64/mkl_csr_f.csv')
data_csr_64_f = [row[7] if not np.isnan(row[7]) else 0 for row in data2.values ]
data3 = pd.read_csv('validation_n=128/mkl_csr_f.csv')
data_csr_128_f = [row[7] if not np.isnan(row[7]) else 0 for row in data3.values ]
data4 = pd.read_csv('validation_n=256/mkl_csr_f.csv')
data_csr_256_f = [row[7] if not np.isnan(row[7]) else 0 for row in data4.values ]
data5 = pd.read_csv('validation_n=512/mkl_csr_f.csv')
data_csr_512_f = [row[7] if not np.isnan(row[7]) else 0 for row in data5.values ]
data7 = pd.read_csv('validation_n=42/mkl_csr_f.csv')
data_csr_42_f = [row[7] if not np.isnan(row[7]) else 0 for row in data7.values ]
data8 = pd.read_csv('validation_n=350/mkl_csr_f.csv')
data_csr_350_f = [row[7] if not np.isnan(row[7]) else 0 for row in data8.values ]
matrices= [row[0][51:-4] for row in data1.values]
data_csr_f = data_csr_32_f+ data_csr_64_f +  data_csr_128_f + data_csr_256_f + data_csr_512_f
# print(data_csr)

data6 = pd.read_csv('validation_spmv/mkl_csr_f.csv')
data_spmv_f = [row[6] if not np.isnan(row[6]) else 0 for row in data6.values ]

# %%
# import matplotlib.pyplot as plt
# import pandas as pd

# Sample data (replace with your actual data)
# %matplotlib inline
data = {
    'SpMV': data_spmv_d,
    'SpMM-32': data_csr_32_d,
    'SpMM-42': data_csr_42_d,
    'SpMM-64': data_csr_64_d,
    'SpMM-128': data_csr_128_d,
    'SpMM-256': data_csr_256_d,
    'SpMM-350': data_csr_350_d,
    'SpMM-512': data_csr_512_d,
}
print(len(data_spmv_d),len(data_csr_32_d),len(csr_matrices))
# Convert data to a DataFrame
df = pd.DataFrame(data, index=csr_matrices)

# Plotting
plt.rcParams['figure.figsize'] = [20, 6] 
plt.figure(figsize=(20, 6))
# df.plot(kind='bar', rot=0, width=0.8)
df.plot(kind='bar', rot=0, width=0.9)
# Customizing labels and title
plt.title('Double MKL CSR', fontsize=14)
# plt.xlabel('Metrics', fontsize=12)
plt.ylabel('GFLOPs', fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.legend(fontsize=10)
plt.xticks(rotation=90)

# Show the plot
plt.show()
# Out:
# 52 52 52

# %%
print(len(data_spmv_f),len(data_csr_32_f), len(data_csr_42_f),len(data_csr_64_f),len(data_csr_256_f),len(data_csr_350_f),len(data_csr_512_f))
# Out:
# 30 30 30 30 30 30 30

# %%
# import matplotlib.pyplot as plt
# import pandas as pd

# Sample data (replace with your actual data)
# %matplotlib inline
data = {
    'SpMV': data_spmv_d[::2],
    'SpMM-32': data_csr_32_d[::2],
    'SpMM-42': data_csr_42_d[::2],
    'SpMM-64': data_csr_64_d[::2],
    'SpMM-128': data_csr_128_d[::2],
    'SpMM-256': data_csr_256_d[::2],
    'SpMM-350': data_csr_350_d[::2],
    'SpMM-512': data_csr_512_d[::2],
}
matrices_to_remove =['scircuit']
filtered_data = {key: data[key] for key in data if key not in matrices_to_remove}
print(len(data_spmv_d),len(data_csr_32_d),len(csr_matrices))
# Convert data to a DataFrame
df = pd.DataFrame(data, index=csr_matrices[::2])

# Plotting
plt.rcParams['figure.figsize'] = [20, 6] 
plt.figure(figsize=(20, 6))
# df.plot(kind='bar', rot=0, width=0.8)
df.plot(kind='bar', rot=0, width=0.9)
# Customizing labels and title
plt.title('Double MKL CSR-first half', fontsize=14)
# plt.xlabel('Metrics', fontsize=12)
plt.ylabel('GFLOPs', fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.legend(fontsize=10)
plt.xticks(rotation=90)

# Show the plot
plt.show()
# Out:
# 52 52 52

# %%
# %matplotlib inline
data = {
    'SpMV': data_spmv_d[1::2],
    'SpMM-32': data_csr_32_d[1::2],
    'SpMM-42': data_csr_42_d[1::2],
    'SpMM-64': data_csr_64_d[1::2],
    'SpMM-128': data_csr_128_d[1::2],
    'SpMM-256': data_csr_256_d[1::2],
    'SpMM-350': data_csr_350_d[1::2],
    'SpMM-512': data_csr_512_d[1::2],
}
matrices_to_remove =['scircuit']
filtered_data = {key: data[key] for key in data if key not in matrices_to_remove}
print(len(data_spmv_d),len(data_csr_32_d),len(csr_matrices))
# Convert data to a DataFrame
df = pd.DataFrame(data, index=csr_matrices[1::2])

# Plotting
plt.rcParams['figure.figsize'] = [20, 6] 
plt.figure(figsize=(20, 6))
# df.plot(kind='bar', rot=0, width=0.8)
df.plot(kind='bar', rot=0, width=0.9)
# Customizing labels and title
plt.title('Double MKL CSR-second half', fontsize=14)
# plt.xlabel('Metrics', fontsize=12)
plt.ylabel('GFLOPs', fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.legend(fontsize=10)
plt.xticks(rotation=90)

# Show the plot
plt.show()
# Out:
# 52 52 52

# %%
# import matplotlib.pyplot as plt
# import pandas as pd

# Sample data (replace with your actual data)
# %matplotlib inline
data = {
    'SpMV': data_spmv_f,
    'SpMM-32': data_csr_32_f,
    'SpMM-42': data_csr_42_f,
    'SpMM-64': data_csr_64_f,
    'SpMM-128': data_csr_128_f,
    'SpMM-256': data_csr_256_f,
    'SpMM-350': data_csr_350_f,
    'SpMM-512': data_csr_512_f,
}

print(len(data_spmv_f),len(data_csr_32_f),len(matrices))
# Convert data to a DataFrame
df = pd.DataFrame(data, index=matrices)

# Plotting
plt.rcParams['figure.figsize'] = [20, 6] 
plt.figure(figsize=(20, 6))
# df.plot(kind='bar', rot=0, width=0.8)
df.plot(kind='bar', rot=0, width=0.95)
# Customizing labels and title
plt.title('Float MKL CSR', fontsize=14)
# plt.xlabel('Metrics', fontsize=12)
plt.ylabel('GFLOPs', fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.legend(fontsize=10)
plt.xticks(rotation=90)

# Show the plot
plt.show()
# Out:
# 30 30 30
